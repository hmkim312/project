# %% [markdown]
# ## naver_place 평점 감성 리뷰

# %%
import time
from sklearn.model_selection import train_test_split
from konlpy.tag import Okt; t = Okt()
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import SMOTE
from nltk import Text
from wordcloud import WordCloud
from collections import Counter
from matplotlib import font_manager, rc
import nltk
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### 데이터 로드

# %%
columns = ['name','loca','writer','review','point','emotion']
raw_datas = pd.read_csv('datas/naver_myplace_review.csv',names = columns)

# %% [markdown]
# #### train, test 나누기

# %%
target = raw_datas['emotion']
X_train, X_test, y_train, y_test = train_test_split(raw_datas, target, train_size=0.7, random_state =13,stratify = target)

# %% [markdown]
# #### 비율 확인
# - 생각보다 비율이 너무 낮음

# %%
X_train.emotion.value_counts() / X_train.emotion.value_counts().sum() * 100
# Out:
# positive    86.829425
# negative    13.170575
# Name: emotion, dtype: float64

# %%
X_test.emotion.value_counts() / X_test.emotion.value_counts().sum() * 100
# Out:
# positive    86.81154
# negative    13.18846
# Name: emotion, dtype: float64

# %% [markdown]
# #### stopword 생성

# %%
# stop_words = pd.read_csv('datas/korean_stopwords.csv',names = ['korean'])
# stop_words = list(stop_words.korean)
# stop_words

# %% [markdown]
# #### 명사 분석 함수(wc 만들기용)

# %%
twitter = Okt()
def tw_tokenizer_nouns(text):
    tokens_ko = twitter.nouns(text)
    return tokens_ko

# %% [markdown]
# #### 명사 빈도 분석

# %%
nouns = []
for i in range(0,len(raw_datas['review'])):
    nouns.extend(tw_tokenizer_nouns(raw_datas['review'][i]))

# %%
wc = WordCloud(background_color = 'white', max_words = 2000)
wc = wc.generate(str(nouns))
wc.words_
# Out:
# {"맛'": 1.0,
#  "분위기'": 0.400609756097561,
#  "맛집'": 0.39634146341463417,
#  "곳'": 0.36890243902439024,
#  "빵'": 0.35,
#  "정말'": 0.31890243902439025,
#  "진짜'": 0.3103658536585366,
#  "가격'": 0.26097560975609757,
#  "카페'": 0.2548780487804878,
#  "음식'": 0.24695121951219512,
#  "커피'": 0.23414634146341465,
#  "사람'": 0.2121951219512195,
#  "좀'": 0.19573170731707318,
#  "직원'": 0.1951219512195122,
#  "더'": 0.1823170731707317,
#  "것'": 0.18048780487804877,
#  "메뉴'": 0.17926829268292682,
#  "추천'": 0.17682926829268292,
#  "때'": 0.16829268292682928,
#  "수'": 0.16463414634146342,
#  "최고'": 0.15426829268292683,
#  "집'": 0.1524390243902439,
#  "사장'": 0.14085365853658535,
#  "생각'": 0.13048780487804879,
#  "밥'": 0.12926829268292683,
#  "파스타'": 0.12378048780487805,
#  "양'": 0.12317073170731707,
#  "주문'": 0.1225609756097561,
#  "여기'": 0.12134146341463414,
#  "조금'": 0.11646341463414635,
#  "또'": 0.11463414634146342,
#  "굿'": 0.11463414634146342,
#  "그냥'": 0.11402439024390244,
#  "정도'": 0.11097560975609756,
#  "시간'": 0.10670731707317073,
#  "뷰'": 0.10548780487804878,
#  "서비스'": 0.10182926829268292,
#  "인테리어'": 0.09939024390243903,
#  "꼭'": 0.09878048780487805,
#  "맛' 요'": 0.09878048780487805,
#  "별로'": 0.0951219512195122,
#  "느낌'": 0.09451219512195122,
#  "다해'": 0.007926829268292683,
#  "채소'": 0.007926829268292683,
#  "좀더'": 0.007926829268292683,
#  "야경'": 0.007926829268292683,
#  "역'": 0.007926829268292683,
#  "일행'": 0.007926829268292683,
#  "케잌'": 0.007926829268292683,
#  "코'": 0.007926829268292683,
#  "제발'": 0.007926829268292683,
#  "별루'": 0.007926829268292683,
#  "사서'": 0.007926829268292683,
#  "마을'": 0.007926829268292683,
#  "연인'": 0.007926829268292683,
#  "또한'": 0.007926829268292683,
#  "덕'": 0.007926829268292683,
#  "하루'": 0.007926829268292683,
#  "질'": 0.007926829268292683,
#  "런치'": 0.007926829268292683,
#  "건강'": 0.007926829268292683,
#  "답'": 0.007926829268292683,
#  "짜장면'": 0.007926829268292683,
#  "환상'": 0.007926829268292683,
#  "바닥'": 0.007926829268292683,
#  "가정식'": 0.007926829268292683,
#  "크게'": 0.007926829268292683,
#  "도로'": 0.007926829268292683,
#  "보이'": 0.007926829268292683,
#  "한편'": 0.007926829268292683,
#  "그닥'": 0.007926829268292683,
#  "예술'": 0.007926829268292683,
#  "김'": 0.007926829268292683,
#  "쥬스'": 0.007926829268292683,
#  "컵'": 0.007926829268292683,
#  "이제'": 0.007926829268292683,
#  "얼마'": 0.007926829268292683,
#  "들깨'": 0.007926829268292683,
#  "계란말이'": 0.007926829268292683,
#  "누룽지'": 0.007926829268292683,
#  "김치찌개'": 0.007926829268292683,
#  "송리단길'": 0.007926829268292683,
#  "쯤'": 0.007926829268292683,
#  "팥'": 0.007926829268292683,
#  "닭볶음탕'": 0.007926829268292683,
#  "음료수'": 0.007926829268292683,
#  "아보카도'": 0.007926829268292683,
#  "도전'": 0.007926829268292683,
#  "편의점'": 0.007926829268292683,
#  "강원도'": 0.007926829268292683,
#  "볶음'": 0.007926829268292683,
#  "옴'": 0.007926829268292683,
#  "치즈케이크'": 0.007926829268292683,
#  "떡'": 0.007926829268292683,
#  "이태원'": 0.007926829268292683,
#  "쑥'": 0.007926829268292683,
#  "오지'": 0.007926829268292683,
#  "피클'": 0.007926829268292683,
#  "꽃게'": 0.007926829268292683,
#  "기'": 0.007926829268292683,
#  "망원동'": 0.007926829268292683,
#  "여의도'": 0.007926829268292683,
#  "짜장'": 0.007926829268292683,
#  "협소'": 0.007926829268292683,
#  "만원'": 0.007926829268292683,
#  "일부러'": 0.007926829268292683,
#  "파김치'": 0.007926829268292683,
#  "마끼'": 0.007926829268292683,
#  "횟집'": 0.007926829268292683,
#  "오이도'": 0.007926829268292683,
#  "동네' 맛집'": 0.007926829268292683,
#  "가격' 대가'": 0.007926829268292683,
#  "돈까스' 소스'": 0.007926829268292683,
#  "요미' 회'": 0.007926829268292683,
#  "곱창' 맛집'": 0.007926829268292683,
#  "집' 근처'": 0.007926829268292683,
#  "빵' 공장'": 0.007926829268292683,
#  "가성' 비도'": 0.007926829268292683,
#  "어' 글리'": 0.007926829268292683,
#  "된장찌개'": 0.007317073170731708,
#  "도우'": 0.007317073170731708,
#  "인정'": 0.007317073170731708,
ko = nltk.Text(nouns, name = 'naver_myplace_review')
print('전체 명사의 갯수 :',len(ko.tokens))
print('유니크한 명사의 갯수 :',len(set(ko.tokens)))
ko.vocab()
# Out:
# 전체 명사의 갯수 : 65266
# 유니크한 명사의 갯수 : 6892
# FreqDist({'맛': 2109, '분위기': 953, '빵': 823, '맛집': 814, '커피': 684, '곳': 653, '가격': 609, '카페': 595, '진짜': 542, '정말': 523, ...})

# %% [markdown]
# #### 한글 설정 및 빈도 그래프 그리기

# %%
plt.rcParams['axes.unicode_minus'] = False

f_path = '/Users/hmkim/AppData/Local/Microsoft/Windows/Fonts/NanumGothicCoding.ttf'

font_name = font_manager.FontProperties(fname = f_path).get_name()
rc('font', family = font_name)

plt.figure(figsize=(24, 8))
ko.plot(50) # 상위 50개
plt.show()

# %% [markdown]
# #### wordcloud 만들기

# %%
data = ko.vocab().most_common(5000)
wordcloud = WordCloud(font_path=f_path,
                      relative_scaling=0.2,
                      background_color='white',
                      ).generate_from_frequencies(dict(data))
plt.figure(figsize=(24, 8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# #### 형태소 분석 함수 (머신러닝 학습용)
# - norm : 정규화
# - stem : 어근화

# %%
twitter = Okt()
def tw_tokenizer(text):
    tokens_ko = twitter.morphs(text, norm=True)
    return tokens_ko

# %%
tfidf_vect = TfidfVectorizer(tokenizer=tw_tokenizer,
                             ngram_range=(1, 2), min_df=3, max_df=0.9,)#,stop_words=stop_words
tfidf_vect.fit(X_train['review'])
tfidf_matrix_train = tfidf_vect.transform(X_train['review'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:507: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn("The parameter 'token_pattern' will not be used"

# %%
print(len(tfidf_vect.get_feature_names()))
docs = tfidf_vect.get_feature_names()
docs
# Out:
# 8181
# ['0',
#  '0001',
#  '0001 f',
#  '1',
#  '1 개',
#  '1 도',
#  '1 메뉴',
#  '1 인',
#  '1 인분',
#  '1 층',
#  '10',
#  '100',
#  '100 프로',
#  '1000원',
#  '10분',
#  '10분 정도',
#  '10시',
#  '11',
#  '11시',
#  '12000원',
#  '12시',
#  '15',
#  '15000원',
#  '15분',
#  '19',
#  '1등',
#  '1시',
#  '1시간',
#  '2',
#  '2 개',
#  '2 명',
#  '2 번',
#  '2 인',
#  '2 인분',
#  '2 층',
#  '20',
#  '200',
#  '200 d',
#  '2000원',
#  '2020년',
#  '20분',
#  '23',
#  '25분',
#  '2시',
#  '2시간',
#  '2천원',
#  '3',
#  '3 개',
#  '3 대',
#  '3 명',
#  '3 인',
#  '3 인분',
#  '3 층',
#  '3000원',
#  '30분',
#  '30분 정도',
#  '34',
#  '35',
#  '3년',
#  '3만원',
#  '3시',
#  '3시 부터',
#  '3월',
#  '4',
#  '4 개',
#  '4 번',
#  '4 인',
#  '4 인분',
#  '40분',
#  '40분 정도',
#  '4만원',
#  '4시',
#  '4시간',
#  '5',
#  '5 개',
#  '5 점',
#  '5 층',
#  '50',
#  '5000원',
#  '500원',
#  '5만원',
#  '5시',
#  '5천원',
#  '6',
#  '6000원',
#  '6500원',
#  '6시',
#  '6천원',
#  '7',
#  '7시',
#  '7천원',
#  '8',
#  '8시',
#  '8천원',
#  '90',
#  '90 d',
#  '9시',
#  'a',
#  'b',
#  'd',
#  'f',
#  'f 90',
#  'g',
#  'good',
#  'httpsmblognavercomblackgta',
#  'jmt',
#  'm',
#  'sns',
#  'sns 에서',
#  'soso',
#  'st',
#  'u',
#  'u 0001',
#  'u 200',
#  'ㄷㄷ',
#  'ㅁ',
#  'ㅅ',
#  'ㅇㅇ',
#  'ㅈ',
#  'ㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ 근데',
#  'ㅋㅋㅋ',
#  'ㅋㅋㅋ 다음',
#  'ㅎ',
#  'ㅎㅎ',
#  'ㅎㅎ 가격',
#  'ㅎㅎ 그리고',
#  'ㅎㅎ 다음',
#  'ㅎㅎ 맛',
#  'ㅎㅎㅎ',
#  'ㅎㅎㅎ 직원',
#  'ㅛ',
#  'ㅜ',
#  'ㅜㅜ',
#  'ㅜㅜㅜ',
#  'ㅜㅠ',
#  'ㅠ',
#  'ㅠ ㅠ',
#  'ㅠㅜ',
#  'ㅠㅠ',
#  'ㅠㅠ 그래도',
#  'ㅠㅠ 그리고',
#  'ㅠㅠ 다음',
#  'ㅠㅠ 여기',
#  'ㅠㅠ 평일',
#  'ㅠㅠㅜ',
#  'ㅠㅠㅠ',
#  'ㅠㅡㅠ',
#  'ㅡ',
#  'ㅡㅡ',
#  '가',
#  '가 가본',
#  '가 가장',
#  '가 고픈',
#  '가 길',
#  '가 길어요',
#  '가 깔끔하고',
#  '가 너무',
#  '가 넓어서',
#  '가 넘',
#  '가 다',
#  '가 다양하고',
#  '가 다양해서',
#  '가 더',
#  '가 돋보이는',
#  '가 되는',
#  '가 두툼',
#  '가 듬뿍',
#  '가 많고',
#  '가 많아서',
#  '가 많은',
#  '가 많이',
#  '가 맛',
#  '가 맛있고',
#  '가 맛있는',
#  '가 맛있다',
#  '가 맛있다고',
#  '가 맛있습니다',
#  '가 맛있어요',
#  '가 맛있었어요',
#  '가 매우',
#  '가 먹어',
#  '가 먹은',
#  '가 먼저',
#  '가 바로',
#  '가 방문',
#  '가 보이는',
#  '가 살짝',
#  '가 생각',
#  '가 쉽지',
#  '가 시킨',
#  '가 싱싱하고',
#  '가 아니라',
#  '가 아쉬워요',
#  '가 아주',
#  '가 안',
#  '가 엄청',
#  '가 없네요',
#  '가 없어서',
#  '가 여기',
#  '가 완전',
#  '가 왜',
#  '가 이',
#  '가 이렇게',
#  '가 인상',
#  '가 일품',
#  '가 있네요',
#  '가 있는',
#  '가 있는데',
#  '가 있어서',
#  '가 있어요',
#  '가 작고',
#  '가 잘',
#  '가 장난',
#  '가 정말',
#  '가 제일',
#  '가 젤',
#  '가 조금',
#  '가 존맛',
#  '가 좀',
#  '가 좋고',
#  '가 좋습니다',
#  '가 좋아서',
#  '가 좋아요',
#  '가 좋아하는',
#  '가 좋았어요',
#  '가 좋은',
#  '가 진짜',
#  '가 짱',
#  '가 참',
#  '가 최고',
#  '가 추천',
#  '가 카페',
#  '가 특히',
#  '가 한',
#  '가 한눈',
#  '가 훨씬',
#  '가게',
#  '가게 가',
#  '가게 내부',
#  '가게 는',
#  '가게 도',
#  '가게 되는',
#  '가게 분위기',
#  '가게 에',
#  '가게 에서',
#  '가게 입니다',
#  '가겠습니다',
#  '가격',
#  '가격 과',
#  '가격 너무',
#  '가격 대',
#  '가격 대가',
#  '가격 대도',
#  '가격 대비',
#  '가격 도',
#  '가격 만',
#  '가격 만큼',
#  '가격 맛',
#  '가격 에',
#  '가격 으로',
#  '가격 은',
#  '가격 이',
#  '가고',
#  '가고 싶네요',
#  '가고 싶어요',
#  '가고 싶은',
#  '가고싶네요',
#  '가고싶어요',
#  '가고싶은',
#  '가기',
#  '가기 도',
#  '가기 좋아요',
#  '가기 좋은',
#  '가긴',
#  '가까운',
#  '가까운 곳',
#  '가까워서',
#  '가끔',
#  '가끔 씩',
#  '가나',
#  '가는',
#  '가는 곳',
#  '가는 길',
#  '가는 길이',
#  '가는 집',
#  '가는거',
#  '가는데',
#  '가능',
#  '가능하고',
#  '가능한',
#  '가능합니다',
#  '가능해서',
#  '가능해요',
#  '가다가',
#  '가도',
#  '가득',
#  '가득한',
#  '가득한 곳',
#  '가라아게',
#  '가래떡',
#  '가려고',
#  '가려구요',
#  '가로수길',
#  '가루',
#  '가리비',
#  '가리비 가',
#  '가마솥',
#  '가면',
#  '가면 꼭',
#  '가면 너무',
#  '가볍게',
#  '가보고',
#  '가보세요',
#  '가본',
#  '가본 카페',
#  '가볼',
#  '가볼만',
#  '가볼만 한',
#  '가볼만 합니다',
#  '가봤는데',
#  '가봤는데 분위기',
#  '가봤는데 진짜',
#  '가봤어요',
#  '가서',
#  '가서 그런지',
#  '가성',
#  '가성 비',
#  '가성 비갑',
#  '가성 비는',
#  '가성 비도',
#  '가세',
#  '가세 요',
#  '가수',
#  '가스',
#  '가시',
#  '가시 면',
#  '가시는',
#  '가심',
#  '가야',
#  '가야 지',
#  '가야겠어요',
#  '가요',
#  '가용',
#  '가운데',
#  '가을',
#  '가장',
#  '가정식',
#  '가져다',
#  '가족',
#  '가족 과',
#  '가족 끼리',
#  '가족 들',
#  '가족 이랑',
#  '가지',
#  '가지 고',
#  '가지 마세요',
#  '가치',
#  '가치 가',
#  '각',
#  '각오',
#  '각자',
#  '간',
#  '간 은',
#  '간 을',
#  '간 친구',
#  '간격',
#  '간격 도',
#  '간격 이',
#  '간다',
#  '간다 면',
#  '간단하게',
#  '간단하게 먹기',
#  '간단한',
#  '간단히',
#  '간도',
#  '간만',
#  '간만 에',
#  '간식',
#  '간이',
#  '간이 너무',
#  '간이 쎈',
#  '간장',
#  '간장 닭갈비',
#  '간장 맛',
#  '간장게장',
#  '간판',
#  '간판 이',
#  '갈',
#  '갈 것',
#  '갈 때',
#  '갈 생각',
#  '갈 수',
#  '갈 예정',
#  '갈 의향',
#  '갈 일',
#  '갈거',
#  '갈거 같아요',
#  '갈거에요',
#  '갈게요',
#  '갈꺼예요',
#  '갈께요',
#  '갈듯',
#  '갈릭',
#  '갈릴듯',
#  '갈비',
#  '갈수',
#  '갈치',
#  '갈치 조림',
#  '갈치 회',
#  '감',
#  '감 바스',
#  '감 이',
#  '감동',
#  '감동 의',
#  '감동 입니다',
#  '감동 적',
#  '감사',
#  '감사 드립니다',
#  '감사합니다',
#  '감사해요',
#  '감사했어요',
#  '감성',
#  '감성 카페',
#  '감수',
#  '감안',
#  '감안 하고',
#  '감자',
#  '감자 튀김',
#  '감자전',
#  '감칠맛',
#  '감탄',
#  '갑',
#  '갑 오브',
#  '갑 입니다',
#  '갑니다',
#  '값',
#  '값 도',
#  '값 은',
#  '값 이',
#  '갓',
#  '갓 덴',
#  '갔네요',
#  '갔는데',
#  '갔는데 너무',
#  '갔는데 사람',
#  '갔는데 역시',
#  '갔는데 커피',
#  '갔는데도',
#  '갔다',
#  '갔다가',
#  '갔더니',
#  '갔던',
#  '갔습니다',
#  '갔어요',
#  '갔었는데',
#  '갔을',
#  '갔을 때',
#  '갔지만',
#  '강',
#  '강 이',
#  '강 추강',
#  '강 추합니다',
#  '강 추해요',
#  '강 한편',
#  '강남',
#  '강남 맛집',
#  '강남 점',
#  '강남역',
#  '강력',
#  '강력 추천',
#  '강릉',
#  '강릉 맛집',
#  '강아지',
#  '강아지 도',
#  '강원도',
#  '강추',
#  '강추 입니다',
#  '강하지',
#  '강한',
#  '강해서',
#  '같',
#  '같고',
#  '같구요',
#  '같네요',
#  '같다',
#  '같습니다',
#  '같아',
#  '같아서',
#  '같아여',
#  '같아요',
#  '같아요 ㅎㅎ',
#  '같아요 ㅠ',
#  '같아요 다음',
#  '같아요 직원',
#  '같아용',
#  '같았어요',
#  '같은',
#  '같은 곳',
#  '같은 느낌',
#  '같은 맛',
#  '같은거',
#  '같은데',
#  '같음',
#  '같이',
#  '같이 간',
#  '같이 나오는',
#  '같이 나온',
#  '같이 먹는',
#  '같이 먹으면',
#  '같이 주는',
#  '같지만',
#  '개',
#  '개 다',
#  '개 만',
#  '개 씩',
#  '개구',
#  '개구 이',
#  '개념',
#  '개도',
#  '개맛',
#  '개선',
#  '개선 이',
#  '개인',
#  '개인 적',
#  '개조',
#  '개조 해서',
#  '개존맛',
#  '갤러리',
#  '갬',
#  '갬 성',
#  '걍',
#  '거',
#  '거 같습니다',
#  '거 같아요',
#  '거 는',
#  '거 먹으러',
#  '거 예요',
#  '거기',
#  '거기 서',
#  '거기 에',
#  '거나',
#  '거려',
#  '거리',
#  '거리 가',
#  '거의',
#  '거의 다',
#  '거의 오픈',
#  '걱정',
#  '걱정 했는데',
#  '건',
#  '건 아니지만',
#  '건강',
#  '건강 식',
#  '건강한',
#  '건강한 맛',
#  '건강해지는',
#  '건강해지는 맛',
#  '건물',
#  '건물 이',
#  '건지',
#  '걸',
#  '걸 추천',
#  '걸려서',
#  '걸려요',
#  '걸렸어요',
#  '걸리지만',
#  '걸립니다',
#  '걸으면',
#  '검색',
#  '검색 해서',
#  '검색 후',
#  '겁나',
#  '것',
#  '것 같네요',
#  '것 같다',
#  '것 같습니다',
#  '것 같아',
#  '것 같아서',
#  '것 같아요',
#  '것 같았어요',
#  '것 같은',
#  '것 같음',
#  '것 도',
#  '것 들',
#  '것 만',
#  '것 에',
#  '것 으로',
#  '것 은',
#  '것 을',
#  '것 이',
#  '것 인데',
#  '것 저',
#  '겉',
#  '겉 은',
#  '겉바',
#  '겉바 속',
#  '겉절이',
#  '게',
#  '게 된',
#  '게 무슨',
#  '게국지',
#  '게다가',
#  '게리',
#  '게리 따',
#  '게살',
#  '게장',
#  '겨우',
#  '겨울',
#  '겨울 에',
#  '겨자',
#  '결국',
#  '결제',
#  '결제 하고',
#  '겸',
#  '경',
#  '경 양식',
#  '경오이',
#  '경오이 시',
#  '경우',
#  '경주',
#  '경치',
#  '경치 가',
#  '경치 도',
#  '경험',
#  '곁들여',
#  '계',
#  '계 수작',
#  '계단',
#  '계단 이',
#  '계란',
#  '계란 이',
#  '계란말이',
#  '계산',
#  '계속',
#  '계속 생각나는',
#  '계수',
#  '계시',
#  '계신',
#  '계절',
#  '고',
#  '고 가기',
#  '고 갔는데',
#  '고 기',
#  '고 기리',
#  '고 너무',
#  '고 맛있어요',
#  '고 보니',
#  '고 분위기',
#  '고 싶은',
#  '고 잉',
#  '고 즈',
#  '고 직원',
#  '고 해서',
#  '고가',
#  '고객',
#  '고구마',
#  '고구마 튀김',
#  '고궁',
#  '고급',
#  '고급 진',
#  '고급 참치',
#  '고급스러운',
#  '고기',
#  '고기 가',
#  '고기 는',
#  '고기 다',
#  '고기 도',
#  '고기 를',
#  '고기국수',
#  '고기랑',
#  '고깃집',
#  '고등',
#  '고등 어회',
#  '고등어',
#  '고르곤졸라',
#  '고르곤졸라 피자',
#  '고를',
#  '고를 수',
#  '고민',
#  '고민 하다가',
#  '고성',
#  '고소하고',
#  '고소한',
#  '고소한 맛',
#  '고소해서',
#  '고양이',
#  '고요',
#  '고추',
#  '고추 튀김',
#  '고추가',
#  '고추장',
#  '고픈',
#  '고픈 곳',
#  '고함',
#  '고해',
#  '고해 서',
#  '고해 요',
#  '골라',
#  '골목',
#  '골목 에',
#  '곱',
#  '곱 도',
#  '곱 배기',
#  '곱 이',
#  '곱창',
#  '곱창 도',
#  '곱창 맛집',
#  '곱창 은',
#  '곱창 집',
#  '곳',
#  '곳 ㅠㅠ',
#  '곳 에',
#  '곳 에서',
#  '곳 으로',
#  '곳 은',
#  '곳 을',
#  '곳 이',
#  '곳 이고',
#  '곳 이네',
#  '곳 이라',
#  '곳 이라서',
#  '곳 이어서',
#  '곳 이에요',
#  '곳 인데',
#  '곳 입니다',
#  '곳 중',
#  '곳 커피',
#  '곳도',
#  '공',
#  '공간',
#  '공간 과',
#  '공간 도',
#  '공간 에',
#  '공간 이',
#  '공간 이라',
#  '공간 이에요',
#  '공기',
#  '공기 가',
#  '공기밥',
#  '공릉',
#  '공부',
#  '공사',
#  '공원',
#  '공장',
#  '공짜',
#  '공짜 로',
#  '과',
#  '과 가격',
#  '과 맛',
#  '과 분위기',
#  '과 음료',
#  '과 음식',
#  '과 직원',
#  '과 카레',
#  '과 커피',
#  '과 함께',
#  '과는',
#  '과도',
#  '과일',
#  '관광지',
#  '관리',
#  '관리 가',
#  '관심',
#  '광안',
#  '광안 리',
#  '광어',
#  '괜찮고',
#  '괜찮네요',
#  '괜찮습니다',
#  '괜찮아서',
#  '괜찮아요',
#  '괜찮았는데',
#  '괜찮았다',
#  '괜찮았습니다',
#  '괜찮았어요',
#  '괜찮았지만',
#  '괜찮은',
#  '괜찮은 곳',
#  '괜찮은 편',
#  '괜찮은데',
#  '괜찮음',
#  '괜춘',
#  '괜히',
#  '굉장히',
#  '교육',
#  '구',
#  '구 냥',
#  '구 여',
#  '구 요',
#  '구 운',
#  '구 이',
#  '구 이집',
#  '구 파스타',
#  '구경',
#  '구경 하는',
#  '구름',
#  '구름 이',
#  '구리',
#  '구매',
#  '구매 했는데',
#  '구분',
#  '구석',
#  '구성',
#  '구성 도',
#  '구성 이',
#  '구수하고',
#  '구워',
#  '구워 먹으면',
#  '구워서',
#  '구워주셔서',
#  '구이',
#  '구이 가',
#  '구이 는',
#  '구이 도',
#  '구이 맛있어요',
#  '구입',
#  '구조',
#  '구청',
#  '국',
#  '국내',
#  '국도',
#  '국물',
#  '국물 까지',
#  '국물 도',
#  '국물 맛',
#  '국물 에',
#  '국물 은',
#  '국물 을',
#  '국물 이',
#  '국밥',
#  '국밥 도',
#  '국밥 맛있어요',
#  '국수',
#  '국수 가',
#  '국수 도',
#  '국수 를',
#  '국수 먹었는데',
#  '국수 와',
#  '국적',
#  '국적 인',
#  '군',
#  '군데',
#  '군자',
#  '굳',
#  '굳 굳',
#  '굳이',
#  '굽기',
#  '굿',
#  '굿 이에요',
#  '굿 즈',
#  '굿굿',
#  '굿굿굿',
#  '궁금해서',
#  '궁금해서 방문',
#  '궁금했는데',
#  '궁합',
#  '궁합 이',
#  '권',
#  '귀여운',
#  '귀엽고',
#  '규',
#  '규 카츠',
#  '규모',
#  '규모 가',
#  '그',
#  '그 니',
#  '그 런가',
#  '그 맛',
#  '그 메뉴',
#  '그 외',
#  '그 자체',
#  '그 정도',
#  '그 중',
#  '그거',
#  '그건',
#  '그것',
#  '그것 도',
#  '그게',
#  '그나마',
#  '그냥',
#  '그냥 그냥',
#  '그냥 그래요',
#  '그냥 그랬어요',
#  '그냥 보통',
#  '그냥 일반',
#  '그냥 저',
#  '그니',
#  '그니 쳐',
#  '그닥',
#  '그대로',
#  '그동안',
#  '그라탕',
#  '그래도',
#  '그래도 맛',
#  '그래도 맛있어요',
#  '그래도 이',
#  '그래서',
#  '그래서 별',
#  '그래요',
#  '그랬어요',
#  '그러나',
#  '그럭저럭',
#  '그런',
#  '그런 곳',
#  '그런 카페',
#  '그런거',
#  '그런것은지',
#  '그런데',
#  '그런지',
#  '그럼',
#  '그렇게',
#  '그렇고',
#  '그렇습니다',
#  '그렇지만',
#  '그릇',
#  '그릇 뚝딱',
#  '그릇 을',
#  '그리',
#  '그리고',
#  '그리고 사장',
#  '그리고 여기',
#  '그린',
#  '그릴',
#  '그림',
#  '그만큼',
#  '그저',
#  '그저 그랬어요',
#  '그치만',
#  '극',
#  '근',
#  '근 케익',
#  '근교',
#  '근데',
#  '근데 가격',
#  '근데 빵',
#  '근데 양',
#  '근데 직원',
#  '근래',
#  '근방',
#  '근처',
#  '근처 라',
#  '근처 에',
#  '근처 에서',
#  '글',
#  '글리',
#  '글리 베이커리',
#  '글쎄요',
#  '금',
#  '금방',
#  '금액',
#  '급',
#  '급하게',
#  '기',
#  '기 가',
#  '기 대',
#  '기 대안',
#  '기 본',
#  '기 시간',
#  '기고',
#  '기기',
#  '기념일',
#  '기념일 에',
#  '기념품',
#  '기는',
#  '기다려서',
#  '기다려서 먹었어요',
#  '기다려야',
#  '기다렸는데',
#  '기다렸다가',
#  '기다렸어요',
#  '기다리고',
#  '기다리는',
#  '기다리는데',
#  '기다리다',
#  '기다리지',
#  '기다린',
#  '기다린 보람',
#  '기다린만큼',
#  '기다릴',
#  '기다림',
#  '기대',
#  '기대 가',
#  '기대 되는',
#  '기대 를',
#  '기대 안',
#  '기대 이상',
#  '기대하고',
#  '기대하고 갔는데',
#  '기대했는데',
#  '기대했던',
#  '기도',
#  '기도 하고',
#  '기류',
#  '기름',
#  '기름 을',
#  '기름 이',
#  '기름기',
#  '기름기 가',
#  ...]

# %% [markdown]
# #### 데이터 불균형 맞추기

# %%
smote = SMOTE(random_state = 13)
X_train_over, y_train_over = smote.fit_sample(tfidf_matrix_train, y_train)

# %%
unique, counts = np.unique(y_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# {'negative': 820, 'positive': 5406}

# %%
unique, counts = np.unique(y_train_over, return_counts=True)
dict(zip(unique, counts))
# Out:
# {'negative': 5406, 'positive': 5406}

# %%
tfidf_vect.get_feature_names()
# Out:
# ['0',
#  '0001',
#  '0001 f',
#  '1',
#  '1 개',
#  '1 도',
#  '1 메뉴',
#  '1 인',
#  '1 인분',
#  '1 층',
#  '10',
#  '100',
#  '100 프로',
#  '1000원',
#  '10분',
#  '10분 정도',
#  '10시',
#  '11',
#  '11시',
#  '12000원',
#  '12시',
#  '15',
#  '15000원',
#  '15분',
#  '19',
#  '1등',
#  '1시',
#  '1시간',
#  '2',
#  '2 개',
#  '2 명',
#  '2 번',
#  '2 인',
#  '2 인분',
#  '2 층',
#  '20',
#  '200',
#  '200 d',
#  '2000원',
#  '2020년',
#  '20분',
#  '23',
#  '25분',
#  '2시',
#  '2시간',
#  '2천원',
#  '3',
#  '3 개',
#  '3 대',
#  '3 명',
#  '3 인',
#  '3 인분',
#  '3 층',
#  '3000원',
#  '30분',
#  '30분 정도',
#  '34',
#  '35',
#  '3년',
#  '3만원',
#  '3시',
#  '3시 부터',
#  '3월',
#  '4',
#  '4 개',
#  '4 번',
#  '4 인',
#  '4 인분',
#  '40분',
#  '40분 정도',
#  '4만원',
#  '4시',
#  '4시간',
#  '5',
#  '5 개',
#  '5 점',
#  '5 층',
#  '50',
#  '5000원',
#  '500원',
#  '5만원',
#  '5시',
#  '5천원',
#  '6',
#  '6000원',
#  '6500원',
#  '6시',
#  '6천원',
#  '7',
#  '7시',
#  '7천원',
#  '8',
#  '8시',
#  '8천원',
#  '90',
#  '90 d',
#  '9시',
#  'a',
#  'b',
#  'd',
#  'f',
#  'f 90',
#  'g',
#  'good',
#  'httpsmblognavercomblackgta',
#  'jmt',
#  'm',
#  'sns',
#  'sns 에서',
#  'soso',
#  'st',
#  'u',
#  'u 0001',
#  'u 200',
#  'ㄷㄷ',
#  'ㅁ',
#  'ㅅ',
#  'ㅇㅇ',
#  'ㅈ',
#  'ㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ 근데',
#  'ㅋㅋㅋ',
#  'ㅋㅋㅋ 다음',
#  'ㅎ',
#  'ㅎㅎ',
#  'ㅎㅎ 가격',
#  'ㅎㅎ 그리고',
#  'ㅎㅎ 다음',
#  'ㅎㅎ 맛',
#  'ㅎㅎㅎ',
#  'ㅎㅎㅎ 직원',
#  'ㅛ',
#  'ㅜ',
#  'ㅜㅜ',
#  'ㅜㅜㅜ',
#  'ㅜㅠ',
#  'ㅠ',
#  'ㅠ ㅠ',
#  'ㅠㅜ',
#  'ㅠㅠ',
#  'ㅠㅠ 그래도',
#  'ㅠㅠ 그리고',
#  'ㅠㅠ 다음',
#  'ㅠㅠ 여기',
#  'ㅠㅠ 평일',
#  'ㅠㅠㅜ',
#  'ㅠㅠㅠ',
#  'ㅠㅡㅠ',
#  'ㅡ',
#  'ㅡㅡ',
#  '가',
#  '가 가본',
#  '가 가장',
#  '가 고픈',
#  '가 길',
#  '가 길어요',
#  '가 깔끔하고',
#  '가 너무',
#  '가 넓어서',
#  '가 넘',
#  '가 다',
#  '가 다양하고',
#  '가 다양해서',
#  '가 더',
#  '가 돋보이는',
#  '가 되는',
#  '가 두툼',
#  '가 듬뿍',
#  '가 많고',
#  '가 많아서',
#  '가 많은',
#  '가 많이',
#  '가 맛',
#  '가 맛있고',
#  '가 맛있는',
#  '가 맛있다',
#  '가 맛있다고',
#  '가 맛있습니다',
#  '가 맛있어요',
#  '가 맛있었어요',
#  '가 매우',
#  '가 먹어',
#  '가 먹은',
#  '가 먼저',
#  '가 바로',
#  '가 방문',
#  '가 보이는',
#  '가 살짝',
#  '가 생각',
#  '가 쉽지',
#  '가 시킨',
#  '가 싱싱하고',
#  '가 아니라',
#  '가 아쉬워요',
#  '가 아주',
#  '가 안',
#  '가 엄청',
#  '가 없네요',
#  '가 없어서',
#  '가 여기',
#  '가 완전',
#  '가 왜',
#  '가 이',
#  '가 이렇게',
#  '가 인상',
#  '가 일품',
#  '가 있네요',
#  '가 있는',
#  '가 있는데',
#  '가 있어서',
#  '가 있어요',
#  '가 작고',
#  '가 잘',
#  '가 장난',
#  '가 정말',
#  '가 제일',
#  '가 젤',
#  '가 조금',
#  '가 존맛',
#  '가 좀',
#  '가 좋고',
#  '가 좋습니다',
#  '가 좋아서',
#  '가 좋아요',
#  '가 좋아하는',
#  '가 좋았어요',
#  '가 좋은',
#  '가 진짜',
#  '가 짱',
#  '가 참',
#  '가 최고',
#  '가 추천',
#  '가 카페',
#  '가 특히',
#  '가 한',
#  '가 한눈',
#  '가 훨씬',
#  '가게',
#  '가게 가',
#  '가게 내부',
#  '가게 는',
#  '가게 도',
#  '가게 되는',
#  '가게 분위기',
#  '가게 에',
#  '가게 에서',
#  '가게 입니다',
#  '가겠습니다',
#  '가격',
#  '가격 과',
#  '가격 너무',
#  '가격 대',
#  '가격 대가',
#  '가격 대도',
#  '가격 대비',
#  '가격 도',
#  '가격 만',
#  '가격 만큼',
#  '가격 맛',
#  '가격 에',
#  '가격 으로',
#  '가격 은',
#  '가격 이',
#  '가고',
#  '가고 싶네요',
#  '가고 싶어요',
#  '가고 싶은',
#  '가고싶네요',
#  '가고싶어요',
#  '가고싶은',
#  '가기',
#  '가기 도',
#  '가기 좋아요',
#  '가기 좋은',
#  '가긴',
#  '가까운',
#  '가까운 곳',
#  '가까워서',
#  '가끔',
#  '가끔 씩',
#  '가나',
#  '가는',
#  '가는 곳',
#  '가는 길',
#  '가는 길이',
#  '가는 집',
#  '가는거',
#  '가는데',
#  '가능',
#  '가능하고',
#  '가능한',
#  '가능합니다',
#  '가능해서',
#  '가능해요',
#  '가다가',
#  '가도',
#  '가득',
#  '가득한',
#  '가득한 곳',
#  '가라아게',
#  '가래떡',
#  '가려고',
#  '가려구요',
#  '가로수길',
#  '가루',
#  '가리비',
#  '가리비 가',
#  '가마솥',
#  '가면',
#  '가면 꼭',
#  '가면 너무',
#  '가볍게',
#  '가보고',
#  '가보세요',
#  '가본',
#  '가본 카페',
#  '가볼',
#  '가볼만',
#  '가볼만 한',
#  '가볼만 합니다',
#  '가봤는데',
#  '가봤는데 분위기',
#  '가봤는데 진짜',
#  '가봤어요',
#  '가서',
#  '가서 그런지',
#  '가성',
#  '가성 비',
#  '가성 비갑',
#  '가성 비는',
#  '가성 비도',
#  '가세',
#  '가세 요',
#  '가수',
#  '가스',
#  '가시',
#  '가시 면',
#  '가시는',
#  '가심',
#  '가야',
#  '가야 지',
#  '가야겠어요',
#  '가요',
#  '가용',
#  '가운데',
#  '가을',
#  '가장',
#  '가정식',
#  '가져다',
#  '가족',
#  '가족 과',
#  '가족 끼리',
#  '가족 들',
#  '가족 이랑',
#  '가지',
#  '가지 고',
#  '가지 마세요',
#  '가치',
#  '가치 가',
#  '각',
#  '각오',
#  '각자',
#  '간',
#  '간 은',
#  '간 을',
#  '간 친구',
#  '간격',
#  '간격 도',
#  '간격 이',
#  '간다',
#  '간다 면',
#  '간단하게',
#  '간단하게 먹기',
#  '간단한',
#  '간단히',
#  '간도',
#  '간만',
#  '간만 에',
#  '간식',
#  '간이',
#  '간이 너무',
#  '간이 쎈',
#  '간장',
#  '간장 닭갈비',
#  '간장 맛',
#  '간장게장',
#  '간판',
#  '간판 이',
#  '갈',
#  '갈 것',
#  '갈 때',
#  '갈 생각',
#  '갈 수',
#  '갈 예정',
#  '갈 의향',
#  '갈 일',
#  '갈거',
#  '갈거 같아요',
#  '갈거에요',
#  '갈게요',
#  '갈꺼예요',
#  '갈께요',
#  '갈듯',
#  '갈릭',
#  '갈릴듯',
#  '갈비',
#  '갈수',
#  '갈치',
#  '갈치 조림',
#  '갈치 회',
#  '감',
#  '감 바스',
#  '감 이',
#  '감동',
#  '감동 의',
#  '감동 입니다',
#  '감동 적',
#  '감사',
#  '감사 드립니다',
#  '감사합니다',
#  '감사해요',
#  '감사했어요',
#  '감성',
#  '감성 카페',
#  '감수',
#  '감안',
#  '감안 하고',
#  '감자',
#  '감자 튀김',
#  '감자전',
#  '감칠맛',
#  '감탄',
#  '갑',
#  '갑 오브',
#  '갑 입니다',
#  '갑니다',
#  '값',
#  '값 도',
#  '값 은',
#  '값 이',
#  '갓',
#  '갓 덴',
#  '갔네요',
#  '갔는데',
#  '갔는데 너무',
#  '갔는데 사람',
#  '갔는데 역시',
#  '갔는데 커피',
#  '갔는데도',
#  '갔다',
#  '갔다가',
#  '갔더니',
#  '갔던',
#  '갔습니다',
#  '갔어요',
#  '갔었는데',
#  '갔을',
#  '갔을 때',
#  '갔지만',
#  '강',
#  '강 이',
#  '강 추강',
#  '강 추합니다',
#  '강 추해요',
#  '강 한편',
#  '강남',
#  '강남 맛집',
#  '강남 점',
#  '강남역',
#  '강력',
#  '강력 추천',
#  '강릉',
#  '강릉 맛집',
#  '강아지',
#  '강아지 도',
#  '강원도',
#  '강추',
#  '강추 입니다',
#  '강하지',
#  '강한',
#  '강해서',
#  '같',
#  '같고',
#  '같구요',
#  '같네요',
#  '같다',
#  '같습니다',
#  '같아',
#  '같아서',
#  '같아여',
#  '같아요',
#  '같아요 ㅎㅎ',
#  '같아요 ㅠ',
#  '같아요 다음',
#  '같아요 직원',
#  '같아용',
#  '같았어요',
#  '같은',
#  '같은 곳',
#  '같은 느낌',
#  '같은 맛',
#  '같은거',
#  '같은데',
#  '같음',
#  '같이',
#  '같이 간',
#  '같이 나오는',
#  '같이 나온',
#  '같이 먹는',
#  '같이 먹으면',
#  '같이 주는',
#  '같지만',
#  '개',
#  '개 다',
#  '개 만',
#  '개 씩',
#  '개구',
#  '개구 이',
#  '개념',
#  '개도',
#  '개맛',
#  '개선',
#  '개선 이',
#  '개인',
#  '개인 적',
#  '개조',
#  '개조 해서',
#  '개존맛',
#  '갤러리',
#  '갬',
#  '갬 성',
#  '걍',
#  '거',
#  '거 같습니다',
#  '거 같아요',
#  '거 는',
#  '거 먹으러',
#  '거 예요',
#  '거기',
#  '거기 서',
#  '거기 에',
#  '거나',
#  '거려',
#  '거리',
#  '거리 가',
#  '거의',
#  '거의 다',
#  '거의 오픈',
#  '걱정',
#  '걱정 했는데',
#  '건',
#  '건 아니지만',
#  '건강',
#  '건강 식',
#  '건강한',
#  '건강한 맛',
#  '건강해지는',
#  '건강해지는 맛',
#  '건물',
#  '건물 이',
#  '건지',
#  '걸',
#  '걸 추천',
#  '걸려서',
#  '걸려요',
#  '걸렸어요',
#  '걸리지만',
#  '걸립니다',
#  '걸으면',
#  '검색',
#  '검색 해서',
#  '검색 후',
#  '겁나',
#  '것',
#  '것 같네요',
#  '것 같다',
#  '것 같습니다',
#  '것 같아',
#  '것 같아서',
#  '것 같아요',
#  '것 같았어요',
#  '것 같은',
#  '것 같음',
#  '것 도',
#  '것 들',
#  '것 만',
#  '것 에',
#  '것 으로',
#  '것 은',
#  '것 을',
#  '것 이',
#  '것 인데',
#  '것 저',
#  '겉',
#  '겉 은',
#  '겉바',
#  '겉바 속',
#  '겉절이',
#  '게',
#  '게 된',
#  '게 무슨',
#  '게국지',
#  '게다가',
#  '게리',
#  '게리 따',
#  '게살',
#  '게장',
#  '겨우',
#  '겨울',
#  '겨울 에',
#  '겨자',
#  '결국',
#  '결제',
#  '결제 하고',
#  '겸',
#  '경',
#  '경 양식',
#  '경오이',
#  '경오이 시',
#  '경우',
#  '경주',
#  '경치',
#  '경치 가',
#  '경치 도',
#  '경험',
#  '곁들여',
#  '계',
#  '계 수작',
#  '계단',
#  '계단 이',
#  '계란',
#  '계란 이',
#  '계란말이',
#  '계산',
#  '계속',
#  '계속 생각나는',
#  '계수',
#  '계시',
#  '계신',
#  '계절',
#  '고',
#  '고 가기',
#  '고 갔는데',
#  '고 기',
#  '고 기리',
#  '고 너무',
#  '고 맛있어요',
#  '고 보니',
#  '고 분위기',
#  '고 싶은',
#  '고 잉',
#  '고 즈',
#  '고 직원',
#  '고 해서',
#  '고가',
#  '고객',
#  '고구마',
#  '고구마 튀김',
#  '고궁',
#  '고급',
#  '고급 진',
#  '고급 참치',
#  '고급스러운',
#  '고기',
#  '고기 가',
#  '고기 는',
#  '고기 다',
#  '고기 도',
#  '고기 를',
#  '고기국수',
#  '고기랑',
#  '고깃집',
#  '고등',
#  '고등 어회',
#  '고등어',
#  '고르곤졸라',
#  '고르곤졸라 피자',
#  '고를',
#  '고를 수',
#  '고민',
#  '고민 하다가',
#  '고성',
#  '고소하고',
#  '고소한',
#  '고소한 맛',
#  '고소해서',
#  '고양이',
#  '고요',
#  '고추',
#  '고추 튀김',
#  '고추가',
#  '고추장',
#  '고픈',
#  '고픈 곳',
#  '고함',
#  '고해',
#  '고해 서',
#  '고해 요',
#  '골라',
#  '골목',
#  '골목 에',
#  '곱',
#  '곱 도',
#  '곱 배기',
#  '곱 이',
#  '곱창',
#  '곱창 도',
#  '곱창 맛집',
#  '곱창 은',
#  '곱창 집',
#  '곳',
#  '곳 ㅠㅠ',
#  '곳 에',
#  '곳 에서',
#  '곳 으로',
#  '곳 은',
#  '곳 을',
#  '곳 이',
#  '곳 이고',
#  '곳 이네',
#  '곳 이라',
#  '곳 이라서',
#  '곳 이어서',
#  '곳 이에요',
#  '곳 인데',
#  '곳 입니다',
#  '곳 중',
#  '곳 커피',
#  '곳도',
#  '공',
#  '공간',
#  '공간 과',
#  '공간 도',
#  '공간 에',
#  '공간 이',
#  '공간 이라',
#  '공간 이에요',
#  '공기',
#  '공기 가',
#  '공기밥',
#  '공릉',
#  '공부',
#  '공사',
#  '공원',
#  '공장',
#  '공짜',
#  '공짜 로',
#  '과',
#  '과 가격',
#  '과 맛',
#  '과 분위기',
#  '과 음료',
#  '과 음식',
#  '과 직원',
#  '과 카레',
#  '과 커피',
#  '과 함께',
#  '과는',
#  '과도',
#  '과일',
#  '관광지',
#  '관리',
#  '관리 가',
#  '관심',
#  '광안',
#  '광안 리',
#  '광어',
#  '괜찮고',
#  '괜찮네요',
#  '괜찮습니다',
#  '괜찮아서',
#  '괜찮아요',
#  '괜찮았는데',
#  '괜찮았다',
#  '괜찮았습니다',
#  '괜찮았어요',
#  '괜찮았지만',
#  '괜찮은',
#  '괜찮은 곳',
#  '괜찮은 편',
#  '괜찮은데',
#  '괜찮음',
#  '괜춘',
#  '괜히',
#  '굉장히',
#  '교육',
#  '구',
#  '구 냥',
#  '구 여',
#  '구 요',
#  '구 운',
#  '구 이',
#  '구 이집',
#  '구 파스타',
#  '구경',
#  '구경 하는',
#  '구름',
#  '구름 이',
#  '구리',
#  '구매',
#  '구매 했는데',
#  '구분',
#  '구석',
#  '구성',
#  '구성 도',
#  '구성 이',
#  '구수하고',
#  '구워',
#  '구워 먹으면',
#  '구워서',
#  '구워주셔서',
#  '구이',
#  '구이 가',
#  '구이 는',
#  '구이 도',
#  '구이 맛있어요',
#  '구입',
#  '구조',
#  '구청',
#  '국',
#  '국내',
#  '국도',
#  '국물',
#  '국물 까지',
#  '국물 도',
#  '국물 맛',
#  '국물 에',
#  '국물 은',
#  '국물 을',
#  '국물 이',
#  '국밥',
#  '국밥 도',
#  '국밥 맛있어요',
#  '국수',
#  '국수 가',
#  '국수 도',
#  '국수 를',
#  '국수 먹었는데',
#  '국수 와',
#  '국적',
#  '국적 인',
#  '군',
#  '군데',
#  '군자',
#  '굳',
#  '굳 굳',
#  '굳이',
#  '굽기',
#  '굿',
#  '굿 이에요',
#  '굿 즈',
#  '굿굿',
#  '굿굿굿',
#  '궁금해서',
#  '궁금해서 방문',
#  '궁금했는데',
#  '궁합',
#  '궁합 이',
#  '권',
#  '귀여운',
#  '귀엽고',
#  '규',
#  '규 카츠',
#  '규모',
#  '규모 가',
#  '그',
#  '그 니',
#  '그 런가',
#  '그 맛',
#  '그 메뉴',
#  '그 외',
#  '그 자체',
#  '그 정도',
#  '그 중',
#  '그거',
#  '그건',
#  '그것',
#  '그것 도',
#  '그게',
#  '그나마',
#  '그냥',
#  '그냥 그냥',
#  '그냥 그래요',
#  '그냥 그랬어요',
#  '그냥 보통',
#  '그냥 일반',
#  '그냥 저',
#  '그니',
#  '그니 쳐',
#  '그닥',
#  '그대로',
#  '그동안',
#  '그라탕',
#  '그래도',
#  '그래도 맛',
#  '그래도 맛있어요',
#  '그래도 이',
#  '그래서',
#  '그래서 별',
#  '그래요',
#  '그랬어요',
#  '그러나',
#  '그럭저럭',
#  '그런',
#  '그런 곳',
#  '그런 카페',
#  '그런거',
#  '그런것은지',
#  '그런데',
#  '그런지',
#  '그럼',
#  '그렇게',
#  '그렇고',
#  '그렇습니다',
#  '그렇지만',
#  '그릇',
#  '그릇 뚝딱',
#  '그릇 을',
#  '그리',
#  '그리고',
#  '그리고 사장',
#  '그리고 여기',
#  '그린',
#  '그릴',
#  '그림',
#  '그만큼',
#  '그저',
#  '그저 그랬어요',
#  '그치만',
#  '극',
#  '근',
#  '근 케익',
#  '근교',
#  '근데',
#  '근데 가격',
#  '근데 빵',
#  '근데 양',
#  '근데 직원',
#  '근래',
#  '근방',
#  '근처',
#  '근처 라',
#  '근처 에',
#  '근처 에서',
#  '글',
#  '글리',
#  '글리 베이커리',
#  '글쎄요',
#  '금',
#  '금방',
#  '금액',
#  '급',
#  '급하게',
#  '기',
#  '기 가',
#  '기 대',
#  '기 대안',
#  '기 본',
#  '기 시간',
#  '기고',
#  '기기',
#  '기념일',
#  '기념일 에',
#  '기념품',
#  '기는',
#  '기다려서',
#  '기다려서 먹었어요',
#  '기다려야',
#  '기다렸는데',
#  '기다렸다가',
#  '기다렸어요',
#  '기다리고',
#  '기다리는',
#  '기다리는데',
#  '기다리다',
#  '기다리지',
#  '기다린',
#  '기다린 보람',
#  '기다린만큼',
#  '기다릴',
#  '기다림',
#  '기대',
#  '기대 가',
#  '기대 되는',
#  '기대 를',
#  '기대 안',
#  '기대 이상',
#  '기대하고',
#  '기대하고 갔는데',
#  '기대했는데',
#  '기대했던',
#  '기도',
#  '기도 하고',
#  '기류',
#  '기름',
#  '기름 을',
#  '기름 이',
#  '기름기',
#  '기름기 가',
#  ...]

# %% [markdown]
# #### 학습 및 검증

# %%
# lgbm
start_time = time.time()
lgbm_clf = LGBMClassifier(n_estimators = 400)
lgbm_clf.fit(X_train_over, y_train_over)
# lgbm_clf.fit(tfidf_matrix_train, y_train)
print('Fit time : ', time.time() - start_time)
skfold = StratifiedKFold(n_splits=5)
cross_val_score(lgbm_clf, X_train_over, y_train_over, scoring=None, cv=skfold)
# cross_val_score(lgbm_clf, tfidf_matrix_train, y_train, scoring=None, cv=skfold)
# Out:
# Fit time :  5.706697702407837
# array([0.85067037, 0.91863153, 0.92368178, 0.92414431, 0.92414431])

# %%
# randomforest
start_time = time.time()
random_clf = RandomForestClassifier(random_state=13,max_depth=5)
random_clf.fit(X_train_over, y_train_over)
# random_clf.fit(tfidf_matrix_train, y_train)
print('Fit time : ', time.time() - start_time)
skfold = StratifiedKFold(n_splits=5)
cross_val_score(random_clf, X_train_over, y_train_over, scoring=None, cv=skfold)
# cross_val_score(random_clf, tfidf_matrix_train, y_train, scoring=None, cv=skfold)
# Out:
# Fit time :  0.31621360778808594
# array([0.74757282, 0.75312067, 0.79370953, 0.78029602, 0.79278446])

# %%
# decisiontree
start_time = time.time()
tree_clf = DecisionTreeClassifier(random_state=13,max_depth=5)
tree_clf.fit(X_train_over, y_train_over)
# tree_clf.fit(tfidf_matrix_train, y_train)
print('Fit time : ', time.time() - start_time)
skfold = StratifiedKFold(n_splits=5)
cross_val_score(tree_clf, X_train_over, y_train_over, scoring=None, cv=skfold)
# cross_val_score(tree_clf, tfidf_matrix_train, y_train, scoring=None, cv=skfold)
# Out:
# Fit time :  0.11269807815551758
# array([0.63569117, 0.65557097, 0.67021277, 0.6692877 , 0.66558742])

# %% [markdown]
# #### 테스트 어큐러시 확인

# %%
tfidf_matrix_test = tfidf_vect.transform(X_test['review'])
preds = lgbm_clf.predict(tfidf_matrix_test)
accuracy_score(y_test, preds)
# Out:
# 0.849756463094792

# %%
tfidf_matrix_test = tfidf_vect.transform(X_test['review'])
preds = random_clf.predict(tfidf_matrix_test)
accuracy_score(y_test, preds)
# Out:
# 0.8242787560884226

# %%
tfidf_matrix_test = tfidf_vect.transform(X_test['review'])
preds = tree_clf.predict(tfidf_matrix_test)
accuracy_score(y_test, preds)
# Out:
# 0.7954289996253279

# %% [markdown]
# #### 실제 문장 넣고 확인

# %%
X_test[['review','emotion']].iloc[333]
# Out:
# review     옆에 맛나 식당이 재료가 소진되어서 주변에 있는 장승포식당에 들렀는데 맛나식당은 1...
# emotion                                             negative
# Name: 6307, dtype: object

# %%
lgbm_clf.predict(tfidf_vect.transform([X_test['review'][6307]]))
# Out:
# array(['positive'], dtype=object)

# %%
random_clf.predict(tfidf_vect.transform([X_test['review'][6307]]))
# Out:
# array(['negative'], dtype=object)

# %%
tree_clf.predict(tfidf_vect.transform([X_test['review'][6307]]))
# Out:
# array(['negative'], dtype=object)

# %% [markdown]
# #### 감성 분류 적용

# %%
word = '별로에요'
print(f'"{word}"는 lgbm에서',lgbm_clf.predict(tfidf_vect.transform([word])))
print(f'"{word}"는 random_forest에서',random_clf.predict(tfidf_vect.transform([word])))
print(f'"{word}"는 decisiontree에서',tree_clf.predict(tfidf_vect.transform([word])))
# Out:
# "별로에요"는 lgbm에서 ['negative']
# "별로에요"는 random_forest에서 ['positive']
# "별로에요"는 decisiontree에서 ['negative']

# %%
word = '싫어요'
print(f'"{word}"는 lgbm에서',lgbm_clf.predict(tfidf_vect.transform([word])))
print(f'"{word}"는 random_forest에서',random_clf.predict(tfidf_vect.transform([word])))
print(f'"{word}"는 decisiontree에서',tree_clf.predict(tfidf_vect.transform([word])))
# Out:
# "싫어요"는 lgbm에서 ['negative']
# "싫어요"는 random_forest에서 ['positive']
# "싫어요"는 decisiontree에서 ['positive']

# %%
word = '맛없어요'
print(f'"{word}"는 lgbm에서',lgbm_clf.predict(tfidf_vect.transform([word])))
print(f'"{word}"는 random_forest에서',random_clf.predict(tfidf_vect.transform([word])))
print(f'"{word}"는 decisiontree에서',tree_clf.predict(tfidf_vect.transform([word])))
# Out:
# "맛없어요"는 lgbm에서 ['negative']
# "맛없어요"는 random_forest에서 ['positive']
# "맛없어요"는 decisiontree에서 ['positive']

# %%
word = '불친절 해요'
print(f'"{word}"는 lgbm에서',lgbm_clf.predict(tfidf_vect.transform([word])))
print(f'"{word}"는 random_forest에서',random_clf.predict(tfidf_vect.transform([word])))
print(f'"{word}"는 decisiontree에서',tree_clf.predict(tfidf_vect.transform([word])))
# Out:
# "불친절 해요"는 lgbm에서 ['negative']
# "불친절 해요"는 random_forest에서 ['negative']
# "불친절 해요"는 decisiontree에서 ['positive']

# %%
word = '친절 합니다'
print(f'"{word}"는 lgbm에서',lgbm_clf.predict(tfidf_vect.transform([word])))
print(f'"{word}"는 random_forest에서',random_clf.predict(tfidf_vect.transform([word])))
print(f'"{word}"는 decisiontree에서',tree_clf.predict(tfidf_vect.transform([word])))
# Out:
# "친절 합니다"는 lgbm에서 ['positive']
# "친절 합니다"는 random_forest에서 ['positive']
# "친절 합니다"는 decisiontree에서 ['positive']

# %%
word = '맛은 있지만 비싸요'
print(f'"{word}"는 lgbm에서',lgbm_clf.predict(tfidf_vect.transform([word])))
print(f'"{word}"는 random_forest에서',random_clf.predict(tfidf_vect.transform([word])))
print(f'"{word}"는 decisiontree에서',tree_clf.predict(tfidf_vect.transform([word])))
# Out:
# "맛은 있지만 비싸요"는 lgbm에서 ['negative']
# "맛은 있지만 비싸요"는 random_forest에서 ['negative']
# "맛은 있지만 비싸요"는 decisiontree에서 ['negative']

# %%
word = '더러워요'
print(f'"{word}"는 lgbm에서',lgbm_clf.predict(tfidf_vect.transform([word])))
print(f'"{word}"는 random_forest에서',random_clf.predict(tfidf_vect.transform([word])))
print(f'"{word}"는 decisiontree에서',tree_clf.predict(tfidf_vect.transform([word])))
# Out:
# "더러워요"는 lgbm에서 ['negative']
# "더러워요"는 random_forest에서 ['positive']
# "더러워요"는 decisiontree에서 ['positive']
